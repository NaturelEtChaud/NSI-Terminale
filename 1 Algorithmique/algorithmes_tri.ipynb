# %% [markdown]
# # Rappels sur les Algorithmes de tri vus en Première

# %% [markdown]
# Pour commencer, on va créer un tableau contenant des nombres tirés au hasard.

# %%
from random import randint

# taille du tableau
n = 20

# création par compréhension
T=[randint (0 ,100) for i in range(n)]

# %% [markdown]
# On peut afficher `T`

# %%
T
# Out:
# [88, 64, 87, 33, 93, 3, 42, 55, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]

# %% [markdown]
# # Algorithme de tri par insertion

# %%
def tri_insertion(T, verbose=False):
    '''
    Entrées :
        T est un tableau d'entiers
        verbose par défaut vaut False. Si verbose vaut True, on affiche toutes les étapes
    Sortie : le tableau T avec les nombres triés dans l'ordre croissant
    '''
    
    # Avant de commencer le tri du tableau
    if verbose== True:
            print(T)
    
    # On commence le tri
    for i in range(1,len(T)) :
        # on prend un nouvel indice
        j = i
        while (j > 0) and (T[j-1] > T[j]) :
            # tant qu'à gauche, il y a un élément plus grand
            # on les échange
            T[j], T[j-1] = T[j-1], T[j]
            j = j - 1
        if verbose== True:
            print(T)

    return T

# %%
tri_insertion(T, True)
# Out:
# [88, 64, 87, 33, 93, 3, 42, 55, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [64, 88, 87, 33, 93, 3, 42, 55, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [64, 87, 88, 33, 93, 3, 42, 55, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [33, 64, 87, 88, 93, 3, 42, 55, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [33, 64, 87, 88, 93, 3, 42, 55, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [3, 33, 64, 87, 88, 93, 42, 55, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [3, 33, 42, 64, 87, 88, 93, 55, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [3, 33, 42, 55, 64, 87, 88, 93, 70, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [3, 33, 42, 55, 64, 70, 87, 88, 93, 29, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [3, 29, 33, 42, 55, 64, 70, 87, 88, 93, 58, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [3, 29, 33, 42, 55, 58, 64, 70, 87, 88, 93, 62, 58, 57, 38, 27, 45, 32, 64, 97]
# [3, 29, 33, 42, 55, 58, 62, 64, 70, 87, 88, 93, 58, 57, 38, 27, 45, 32, 64, 97]
# [3, 29, 33, 42, 55, 58, 58, 62, 64, 70, 87, 88, 93, 57, 38, 27, 45, 32, 64, 97]
# [3, 29, 33, 42, 55, 57, 58, 58, 62, 64, 70, 87, 88, 93, 38, 27, 45, 32, 64, 97]
# [3, 29, 33, 38, 42, 55, 57, 58, 58, 62, 64, 70, 87, 88, 93, 27, 45, 32, 64, 97]
# [3, 27, 29, 33, 38, 42, 55, 57, 58, 58, 62, 64, 70, 87, 88, 93, 45, 32, 64, 97]
# [3, 27, 29, 33, 38, 42, 45, 55, 57, 58, 58, 62, 64, 70, 87, 88, 93, 32, 64, 97]
# [3, 27, 29, 32, 33, 38, 42, 45, 55, 57, 58, 58, 62, 64, 70, 87, 88, 93, 64, 97]
# [3, 27, 29, 32, 33, 38, 42, 45, 55, 57, 58, 58, 62, 64, 64, 70, 87, 88, 93, 97]
# [3, 27, 29, 32, 33, 38, 42, 45, 55, 57, 58, 58, 62, 64, 64, 70, 87, 88, 93, 97]
# [3, 27, 29, 32, 33, 38, 42, 45, 55, 57, 58, 58, 62, 64, 64, 70, 87, 88, 93, 97]
